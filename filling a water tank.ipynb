# %%
from scipy.integrate import  odeint
import numpy as np 
import matplotlib.pyplot as plt

# %%
def model(h,t):
    c=50
    pie=3.14
    r=1
    row=1000
    u = (100-0) / (2-7) * (t-0) + 100 
    #taking u as a function of time 
     
    # if t>=2 and t<=7:
    #     u=100
    # else:
    #     u=0
    if u<0:
        u=20
    dhdt= (c * u) /( (r**2) * row) + 0
    return dhdt
h0=0
t=np.linspace(0,10, 101)
u = (100-0) / (2-7) * (t-0) + 100 

h=odeint(model,h0,t )
plt.plot(t,h)
plt.xlabel('time')
plt.ylabel('height')
plt.show()
